# %% [markdown]
# # **EMPLOYEE ACCESS IN AMAZON.COM**

# %% [markdown]
# *Build algorithm to predict approval  or denial for an unseen employees*

# %% [markdown]
# 0->Denial
# 1->Approve

# %% [markdown]
# <!-- from IPython.display import Image -->
# ![image.png](attachment:ea06f040-afc0-4717-b2c5-fd7de9e61ae0.png)

# %%
from pyforest import*
lazy_imports()
# Out:
# ['import imutils',
#  'from sklearn.preprocessing import RobustScaler',
#  'from sklearn.model_selection import cross_val_score',
#  'from scipy import signal as sg',
#  'import lightgbm as lgb',
#  'import fastai',
#  'from sklearn.ensemble import RandomForestRegressor',
#  'import altair as alt',
#  'import pandas as pd',
#  'from sklearn.preprocessing import PolynomialFeatures',
#  'import plotly.graph_objs as go',
#  'from scipy import stats',
#  'from sklearn.preprocessing import MinMaxScaler',
#  'from pyspark import SparkContext',
#  'from sklearn.model_selection import GridSearchCV',
#  'from sklearn.feature_extraction.text import TfidfVectorizer',
#  'import torch',
#  'import nltk',
#  'from sklearn.model_selection import RandomizedSearchCV',
#  'import plotly.express as px',
#  'import statsmodels.api as sm',
#  'import pickle',
#  'from sklearn.linear_model import Lasso',
#  'from sklearn.linear_model import LassoCV',
#  'import spacy',
#  'import xgboost as xgb',
#  'from sklearn.manifold import TSNE',
#  'import gensim',
#  'import fbprophet',
#  'from sklearn import metrics',
#  'from openpyxl import load_workbook',
#  'from sklearn.linear_model import Ridge',
#  'import tensorflow as tf',
#  'from sklearn.linear_model import LinearRegression',
#  'from sklearn.model_selection import KFold',
#  'from xlrd import open_workbook',
#  'from dask import dataframe as dd',
#  'from sklearn.preprocessing import LabelEncoder',
#  'import skimage',
#  'from sklearn.model_selection import StratifiedKFold',
#  'import plotly as py',
#  'import matplotlib as mpl',
#  'from pathlib import Path',
#  'import sklearn',
#  'from sklearn.linear_model import RidgeCV',
#  'import glob',
#  'import cv2',
#  'from sklearn.impute import SimpleImputer',
#  'from sklearn.ensemble import GradientBoostingRegressor',
#  'from sklearn.linear_model import ElasticNet',
#  'import numpy as np',
#  'from sklearn.ensemble import RandomForestClassifier',
#  'import statistics',
#  'import matplotlib.pyplot as plt',
#  'import bokeh',
#  'import pydot',
#  'from sklearn.feature_extraction.text import CountVectorizer',
#  'from sklearn.model_selection import train_test_split',
#  'import awswrangler as wr',
#  'from statsmodels.tsa.arima_model import ARIMA',
#  'from sklearn.ensemble import GradientBoostingClassifier',
#  'from sklearn.linear_model import ElasticNetCV',
#  'from sklearn import svm',
#  'import seaborn as sns',
#  'import os',
#  'from sklearn.preprocessing import StandardScaler',
#  'from sklearn.cluster import KMeans',
#  'import datetime as dt',
#  'from PIL import Image',
#  'import re',
#  'from sklearn.preprocessing import OneHotEncoder',
#  'from fbprophet import Prophet',
#  'import tqdm',
#  'import sys',
#  'from sklearn.decomposition import PCA',
#  'import dash',
#  'import keras',
#  'from sklearn.linear_model import LogisticRegression',
#  'import textblob']

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     39353   85475         117961         118300         123472
# 1           1     17183    1540         117961         118343         123125
# 2           1     36724   14457         118219         118220         117884
# 3           1     36135    5396         117961         118343         119993
# 4           1     42680    5905         117929         117930         119569
# ...       ...       ...     ...            ...            ...            ...
# 32764       1     23497   16971         117961         118300         119993
# 32765       1     25139  311198          91261         118026         122392
# 32766       1     34924   28805         117961         118327         120299
# 32767       1     80574   55643         118256         118257         117945
# 32768       1     14354   59575         117916         118150         117920
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0          117905            117906       290919     117908
# 1          118536            118536       308574     118539
# 2          117879            267952        19721     117880
# 3          118321            240983       290919     118322
# 4          119323            123932        19793     119325
# ...           ...               ...          ...        ...
# 32764      118321            240983       290919     118322
# 32765      121143            173805       249618     121145
# 32766      124922            152038       118612     124924
# 32767      280788            280788       292795     119082
# 32768      118568            122142        19721     118570
#
# [32769 rows x 10 columns]

# %%
test = pd.read_csv("test.csv")

# %%
test
# Out:
#           id  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0          1     78766   72734         118079         118080         117878
# 1          2     40644    4378         117961         118327         118507
# 2          3     75443    2395         117961         118300         119488
# 3          4     43219   19986         117961         118225         118403
# 4          5     42093   50015         117961         118343         119598
# ...      ...       ...     ...            ...            ...            ...
# 58916  58917     75078    4565         117961         118386         121961
# 58917  58918      6977   72209         117961         118225         124948
# 58918  58919     39262    6114         117961         118343           6104
# 58919  58920      1023    8674         117961         118327         120318
# 58920  58921     44977    3918         117961         118343         118660
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0          117879            118177        19721     117880
# 1          118863            122008       118398     118865
# 2          118172            301534       249618     118175
# 3          120773            136187       118960     120774
# 4          118422            300136       118424     118425
# ...           ...               ...          ...        ...
# 58916      118784            117906       290919     118786
# 58917      118054            118054       117887     118055
# 58918      118278            118260       290919     118279
# 58919      118321            117906       290919     118322
# 58920      119433            133686       118424     119435
#
# [58921 rows x 10 columns]

# %%
print("The size of train data",train.shape)
print("The size of test data",test.shape)
# Out:
# The size of train data (32769, 10)
# The size of test data (58921, 10)

# %%
for i in train.columns:
    print(i)
# Out:
# ACTION
# RESOURCE
# MGR_ID
# ROLE_ROLLUP_1
# ROLE_ROLLUP_2
# ROLE_DEPTNAME
# ROLE_TITLE
# ROLE_FAMILY_DESC
# ROLE_FAMILY
# ROLE_CODE

# %%
for  i in test.columns:
    print(i)
# Out:
# id
# RESOURCE
# MGR_ID
# ROLE_ROLLUP_1
# ROLE_ROLLUP_2
# ROLE_DEPTNAME
# ROLE_TITLE
# ROLE_FAMILY_DESC
# ROLE_FAMILY
# ROLE_CODE

# %% [markdown]
# *WE CAN SEE THAT TRAIN HAS ACTION AND TEST DOESNT HAVE ACTION WHICH IS THE TARGET VARIABLE*

# %% [markdown]
# **CATBOOST**
# (CAT->CATEGORICAL)

# %%
#!pip  install catboost

# %%
from catboost.datasets import amazon # we have imported from catboost

traindf , testdf = amazon()

# %%
print("The size of train data ",traindf.shape)
print("The size of test data ",testdf.shape)
# Out:
# The size of train data  (32769, 10)
# The size of test data  (58921, 10)

# %%
traindf.head()
# Out:
#    ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0       1     39353   85475         117961         118300         123472
# 1       1     17183    1540         117961         118343         123125
# 2       1     36724   14457         118219         118220         117884
# 3       1     36135    5396         117961         118343         119993
# 4       1     42680    5905         117929         117930         119569
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      117905            117906       290919     117908
# 1      118536            118536       308574     118539
# 2      117879            267952        19721     117880
# 3      118321            240983       290919     118322
# 4      119323            123932        19793     119325

# %%
traindf.apply(lambda x:len(x.unique()))
# Out:
# ACTION                 2
# RESOURCE            7518
# MGR_ID              4243
# ROLE_ROLLUP_1        128
# ROLE_ROLLUP_2        177
# ROLE_DEPTNAME        449
# ROLE_TITLE           343
# ROLE_FAMILY_DESC    2358
# ROLE_FAMILY           67
# ROLE_CODE            343
# dtype: int64

# %%
traindf['MGR_ID'].value_counts()
# Out:
# 770      152
# 2270      99
# 2594      82
# 1350      71
# 2014      67
#         ...
# 97000      1
# 81506      1
# 12517      1
# 50296      1
# 22355      1
# Name: MGR_ID, Length: 4243, dtype: int64

# %% [markdown]
# **DISTRIBUTION OF FEATURES**

# %% [markdown]
# DISPLOT

# %%
traindf.describe()
# Out:
#              ACTION       RESOURCE         MGR_ID  ROLE_ROLLUP_1  \
# count  32769.000000   32769.000000   32769.000000   32769.000000
# mean       0.942110   42923.916171   25988.957979  116952.627788
# std        0.233539   34173.892702   35928.031650   10875.563591
# min        0.000000       0.000000      25.000000    4292.000000
# 25%        1.000000   20299.000000    4566.000000  117961.000000
# 50%        1.000000   35376.000000   13545.000000  117961.000000
# 75%        1.000000   74189.000000   42034.000000  117961.000000
# max        1.000000  312153.000000  311696.000000  311178.000000
#
#        ROLE_ROLLUP_2  ROLE_DEPTNAME     ROLE_TITLE  ROLE_FAMILY_DESC  \
# count   32769.000000   32769.000000   32769.000000      32769.000000
# mean   118301.823156  118912.779914  125916.152644     170178.369648
# std      4551.588572   18961.322917   31036.465825      69509.462130
# min     23779.000000    4674.000000  117879.000000       4673.000000
# 25%    118102.000000  118395.000000  118274.000000     117906.000000
# 50%    118300.000000  118921.000000  118568.000000     128696.000000
# 75%    118386.000000  120535.000000  120006.000000     235280.000000
# max    286791.000000  286792.000000  311867.000000     311867.000000
#
#          ROLE_FAMILY      ROLE_CODE
# count   32769.000000   32769.000000
# mean   183703.408893  119789.430132
# std    100488.407413    5784.275516
# min      3130.000000  117880.000000
# 25%    118363.000000  118232.000000
# 50%    119006.000000  118570.000000
# 75%    290919.000000  119348.000000
# max    308574.000000  270691.000000

# %%
import warnings
warnings.filterwarnings('ignore')
for i in traindf.describe().columns:
    sns.distplot(traindf[i].dropna())
    plt.show()

# %% [markdown]
# *BOXPLOT*

# %%
traindf['ACTION'].value_counts() # Data imbalance
# Out:
# 1    30872
# 0     1897
# Name: ACTION, dtype: int64

# %%
for i in traindf.describe().columns:
    sns.boxplot(traindf[i].dropna())
    plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(traindf.corr(),annot=True)
plt.show()

# %% [markdown]
# **MODEL BUILDING**

# %%
traindf.head()
# Out:
#    ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0       1     39353   85475         117961         118300         123472
# 1       1     17183    1540         117961         118343         123125
# 2       1     36724   14457         118219         118220         117884
# 3       1     36135    5396         117961         118343         119993
# 4       1     42680    5905         117929         117930         119569
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      117905            117906       290919     117908
# 1      118536            118536       308574     118539
# 2      117879            267952        19721     117880
# 3      118321            240983       290919     118322
# 4      119323            123932        19793     119325

# %%
testdf.head()
# Out:
#    id  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0   1     78766   72734         118079         118080         117878
# 1   2     40644    4378         117961         118327         118507
# 2   3     75443    2395         117961         118300         119488
# 3   4     43219   19986         117961         118225         118403
# 4   5     42093   50015         117961         118343         119598
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      117879            118177        19721     117880
# 1      118863            122008       118398     118865
# 2      118172            301534       249618     118175
# 3      120773            136187       118960     120774
# 4      118422            300136       118424     118425

# %%
x = traindf.drop("ACTION",axis = 1)
y = traindf["ACTION"]
x_test = testdf.drop("id",axis = 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_valid,y_train,y_valid = train_test_split(x,y,test_size = 0.3,random_state = 1)

# %%
from catboost import CatBoostClassifier

# %%
# %%time

params = {'eval_metric':'AUC',
          'verbose':200,
          'random_seed':1
         }

catmodel_1 = CatBoostClassifier(**params)
catmodel_1.fit(x_train,y_train,
               eval_set = (x_valid,y_valid),
               use_best_model=True,
              );
# Out:
# Learning rate set to 0.068702
# 0:	test: 0.5411584	best: 0.5411584 (0)	total: 228ms	remaining: 3m 47s
# 200:	test: 0.8054496	best: 0.8054496 (200)	total: 3.01s	remaining: 12s
# 400:	test: 0.8234160	best: 0.8234160 (400)	total: 5.95s	remaining: 8.88s
# 600:	test: 0.8331189	best: 0.8332287 (587)	total: 8.72s	remaining: 5.79s
# 800:	test: 0.8374659	best: 0.8382637 (781)	total: 11.5s	remaining: 2.85s
# 999:	test: 0.8430064	best: 0.8434854 (989)	total: 14.3s	remaining: 0us
#
# bestTest = 0.8434853835
# bestIteration = 989
#
# Shrink model to first 990 iterations.
# Wall time: 15 s

# %%
x.head()
# Out:
#    RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  ROLE_TITLE  \
# 0     39353   85475         117961         118300         123472      117905
# 1     17183    1540         117961         118343         123125      118536
# 2     36724   14457         118219         118220         117884      117879
# 3     36135    5396         117961         118343         119993      118321
# 4     42680    5905         117929         117930         119569      119323
#
#    ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0            117906       290919     117908
# 1            118536       308574     118539
# 2            267952        19721     117880
# 3            240983       290919     118322
# 4            123932        19793     119325

# %%
categorical_features = list(range(x.shape[1]))
print(categorical_features)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
# %%time

params = {'eval_metric':'AUC',
          'cat_features':categorical_features,
          'verbose':200,
          'random_seed':1
         }

catmodel = CatBoostClassifier(**params)
catmodel.fit(x_train,y_train,
               eval_set = (x_valid,y_valid),
               use_best_model=True,
              );
# Out:
# Learning rate set to 0.068702
# 0:	test: 0.5000000	best: 0.5000000 (0)	total: 33ms	remaining: 33s
# 200:	test: 0.8900235	best: 0.8901240 (197)	total: 16.6s	remaining: 1m 6s
# 400:	test: 0.8934668	best: 0.8935823 (388)	total: 36.3s	remaining: 54.2s
# 600:	test: 0.8945714	best: 0.8948400 (516)	total: 55.8s	remaining: 37s
# 800:	test: 0.8917077	best: 0.8948400 (516)	total: 1m 13s	remaining: 18.4s
# 999:	test: 0.8896660	best: 0.8948400 (516)	total: 1m 32s	remaining: 0us
#
# bestTest = 0.8948400433
# bestIteration = 516
#
# Shrink model to first 517 iterations.
# Wall time: 1min 33s

# %%
feature_imp =catmodel.get_feature_importance(prettified=True)
feature_imp
# Out:
#          Feature Id  Importances
# 0          RESOURCE    19.913241
# 1     ROLE_DEPTNAME    16.512425
# 2            MGR_ID    14.815541
# 3     ROLE_ROLLUP_2    12.460265
# 4  ROLE_FAMILY_DESC     9.947457
# 5        ROLE_TITLE     8.648032
# 6       ROLE_FAMILY     8.073697
# 7     ROLE_ROLLUP_1     6.411501
# 8         ROLE_CODE     3.217841

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6));
sns.barplot(x='Importances',y='Feature Id',data = feature_imp );
plt.title('Catboost features importance');

# %%
predict = catmodel.predict(x_test)

# %%
predict
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
catmodel.score(x_valid,y_valid)
# Out:
# 0.9532092360899196

# %%
traindf['ACTION'].value_counts()
# Out:
# 1    30872
# 0     1897
# Name: ACTION, dtype: int64
